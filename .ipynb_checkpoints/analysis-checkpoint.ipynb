# %% [markdown]
# # K-means|| distribuito su Dask — Analisi
#
# Notebook di orchestrazione: avvia il cluster, carica il dataset, esegue i test (singola run o benchmark su più combinazioni) e salva i risultati in `./results`.
#
# Moduli usati:
# - `kmeans_parallel.py` — algoritmo k-means|| distribuito
# - `launch_cluster.py` — avvio/spegnimento del cluster Dask via SSH
# - `data_loader.py` — caricamento del dataset
# - `benchmark.py` — esecuzione dei test e salvataggio risultati

# %% [markdown]
# ## 1. Import

# %%
import numpy as np
import pandas as pd
from kmeans_parallel import kmeans_parallel
from launch_cluster import launch_cluster, shutdown_cluster
from data_loader import load_dataset
from benchmark import run_single_test, run_benchmark, calculate_inertia

import time

# %% [markdown]
# ## 2. Parametri configurabili
#
# Modifica qui i valori per cambiare numero di worker, `k`, `l` (oversampling factor) e `r` (numero di round dell'inizializzazione parallela).

# %%
# --- Cluster ---
N_WORKERS = 8      # tra 1 e 8 (nodi disponibili in launch_cluster.py)
NUM_PARTITIONS = 8 * N_WORKERS   # regola empirica: >= n_threads_per_worker * n_workers

# --- Algoritmo k-means|| ---
K = 500                # numero di cluster finali
L = 250                # oversampling factor (assoluto). In alternativa: L = round(L_OVER_K * K)
R = 10                  # numero di round dell'inizializzazione parallela
MAX_ITER_FIT = 10      # iterazioni massime della fase di Lloyd's (fit)
SEED = 42

# %%
# --- Dataset ---
DATASET_URL_10PC = "https://ndownloader.figshare.com/files/5976042"
# link used by sklearn function fetch_kddcup99 (original link gives 403 error)
#***for 10% dataset***

DATASET_URL_FULL="https://ndownloader.figshare.com/files/5976045"
#***FULL DATASET***

RAW_GZ_PATH   = "/home/ubuntu/Project/libero_development/data/kddcup_data.gz" # compressed (.gz) dataset file
PARQUET_PATH = '/tmp/kddcup_data.parquet' # single Parquet file (ie a compressed format file but partition-able, unlike .gz) on master

# column names of KDD dataset, from source code of the above sklearn function;
# "protocol_type","service","flag" are non-numeric so they will be dropped later,
# as will be "label" and the constant column 'num_outbound_cmds' 
# (10% dataset might have more constant columns such as 'is_host_login')
COL_NAMES = [
    "duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot",
    "num_failed_logins","logged_in","num_compromised","root_shell",
    "su_attempted","num_root","num_file_creations","num_shells",
    "num_access_files","num_outbound_cmds","is_host_login",
    "is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count",
    "dst_host_srv_count","dst_host_same_srv_rate",
    "dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate",
    "dst_host_srv_serror_rate","dst_host_rerror_rate",
    "dst_host_srv_rerror_rate","label"
]

# %% [markdown]
# ## 3. Avvio del cluster

# %%
# DO NOT RUN if already existing!
cluster, client = launch_cluster(N_WORKERS)
# Out:
# Inizializzazione del cluster SSH con 8 worker...
# Worker selezionati: ['10.67.22.254', '10.67.22.34', '10.67.22.145', '10.67.22.121', '10.67.22.192', '10.67.22.18', '10.67.22.187', '10.67.22.48']
# 2026-07-18 09:25:17,780 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:17,779 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2026-07-18 09:25:17,808 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:17,808 - distributed.scheduler - INFO - State start
# 2026-07-18 09:25:17,812 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:17,811 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.194:8786
# 2026-07-18 09:25:19,158 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,164 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.121:42931'
# 2026-07-18 09:25:19,167 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,173 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.145:37247'
# 2026-07-18 09:25:19,171 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,173 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.254:35427'
# 2026-07-18 09:25:19,221 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,225 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.18:34969'
# 2026-07-18 09:25:19,228 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,234 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.48:44215'
# 2026-07-18 09:25:19,298 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,302 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.187:37231'
# 2026-07-18 09:25:19,299 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,300 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.34:44059'
# 2026-07-18 09:25:19,300 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,304 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.192:37187'
# 2026-07-18 09:25:19,448 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,454 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-qozwazp5', purging
# 2026-07-18 09:25:19,458 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,465 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.121:40827
# 2026-07-18 09:25:19,467 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,469 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-3b3doqkr', purging
# 2026-07-18 09:25:19,478 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,480 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.254:40723
# 2026-07-18 09:25:19,505 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,510 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-di_4l_k8', purging
# 2026-07-18 09:25:19,514 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,519 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-g17y031_', purging
# 2026-07-18 09:25:19,516 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,521 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.145:36301
# 2026-07-18 09:25:19,526 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,530 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.18:46185
# 2026-07-18 09:25:19,567 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,572 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ajqlw_zb', purging
# 2026-07-18 09:25:19,579 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,585 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.48:43043
# 2026-07-18 09:25:19,644 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,647 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-ripc1wfu', purging
# 2026-07-18 09:25:19,650 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,650 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-5ggamaov', purging
# 2026-07-18 09:25:19,657 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,660 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.192:35229
# 2026-07-18 09:25:19,663 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,663 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.34:35017
# 2026-07-18 09:25:19,676 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,679 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-waisssaj', purging
# 2026-07-18 09:25:19,690 - distributed.deploy.ssh - INFO - 2026-07-18 09:25:19,693 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.187:44589
# Cluster avviato e connessione stabilita con successo!

# %% [markdown]
# #### IF INSTEAD ALREADY EXISTING CLUSTER:

# %%
from dask.distributed import Client

SCHEDULER_ADDRESS = "tcp://10.67.22.194:8786"

try:
    client = Client(SCHEDULER_ADDRESS, timeout="10s")
    print("Connected to cluster successfully!")
    print(f"Dask Dashboard link: {client.dashboard_link}")

except Exception as e:
    print(f"Connection error: {e}")
# Out:
# Connected to cluster successfully!
# Dask Dashboard link: http://10.67.22.194:8787/status

# %%
client.scheduler_info()
# Out:
# {'type': 'Scheduler',
#  'id': 'Scheduler-4ac1d1c2-aace-4778-989b-2b986ba65e7e',
#  'address': 'tcp://10.67.22.194:8786',
#  'services': {'dashboard': 8787},
#  'started': 1784366717.460303,
#  'n_workers': 8,
#  'total_threads': 64,
#  'total_memory': 66574651392,
#  'workers': {'tcp://10.67.22.121:40827': {'type': 'Worker',
#    'id': 'tcp://10.67.22.121:40827',
#    'host': '10.67.22.121',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-gd1ug4o8',
#    'name': 'tcp://10.67.22.121:40827',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1784386827.9956636,
#    'services': {'dashboard': 37769},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.0013146400451660156,
#      'tick-duration': 0.49883294105529785},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 142,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 139},
#     'event_loop_interval': 0.01997056007385254,
#     'cpu': 4.0,
#     'memory': 373821440,
#     'time': 1784386827.4931915,
#     'host_net_io': {'read_bps': 261.87251156432546,
#      'write_bps': 1435.3012465892039},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.121:42931'},
#   'tcp://10.67.22.145:36301': {'type': 'Worker',
#    'id': 'tcp://10.67.22.145:36301',
#    'host': '10.67.22.145',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-wiwe8pll',
#    'name': 'tcp://10.67.22.145:36301',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1784386828.0404048,
#    'services': {'dashboard': 43821},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.001477956771850586,
#      'tick-duration': 0.4991035461425781},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 154,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 148},
#     'event_loop_interval': 0.019970364570617676,
#     'cpu': 2.0,
#     'memory': 377651200,
#     'time': 1784386827.5401697,
#     'host_net_io': {'read_bps': 262.52998502165315,
#      'write_bps': 1438.9048034011219},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.145:37247'},
#   'tcp://10.67.22.187:44589': {'type': 'Worker',
#    'id': 'tcp://10.67.22.187:44589',
#    'host': '10.67.22.187',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-3zyjy980',
#    'name': 'tcp://10.67.22.187:44589',
#    'nthreads': 8,
#    'memory_limit': 8321822720,
#    'last_seen': 1784386828.2189074,
#    'services': {'dashboard': 46087},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'tick-duration': 0.5001049041748047,
#      'latency': 0.0041065216064453125},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 165,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 139},
#     'event_loop_interval': 0.02003378391265869,
#     'cpu': 4.0,
#     'memory': 387989504,
#     'time': 1784386827.7201743,
#     'host_net_io': {'read_bps': 993.7362345971042,
#      'write_bps': 2167.424704835535},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.187:37231'},
#   'tcp://10.67.22.18:46185': {'type': 'Worker',
#    'id': 'tcp://10.67.22.18:46185',
#    'host': '10.67.22.18',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-kmuz7y78',
#    'name': 'tcp://10.67.22.18:46185',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1784386828.047986,
#    'services': {'dashboard': 39453},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 70463215.05347171, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'tick-duration': 0.5006632804870605,
#      'latency': 0.0019109249114990234},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 265,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 138},
#     'event_loop_interval': 0.020022621154785158,
#     'cpu': 2.0,
#     'memory': 953569280,
#     'time': 1784386827.5492284,
#     'host_net_io': {'read_bps': 261.77038810795267,
#      'write_bps': 1442.7345054499376},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.18:34969'},
#   'tcp://10.67.22.192:35229': {'type': 'Worker',
#    'id': 'tcp://10.67.22.192:35229',
#    'host': '10.67.22.192',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-qjgs93qr',
#    'name': 'tcp://10.67.22.192:35229',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1784386828.186083,
#    'services': {'dashboard': 36233},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.00393986701965332,
#      'tick-duration': 0.49927854537963867},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 108,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 140},
#     'event_loop_interval': 0.02000157356262207,
#     'cpu': 6.0,
#     'memory': 402944000,
#     'time': 1784386827.6825738,
#     'host_net_io': {'read_bps': 910.7978443108971,
#      'write_bps': 2083.8253976431733},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.192:37187'}}}

# %% [markdown]
# ## 4. Load dataset

# %%
start=time.time()
X_bag, (mean_ar, std_ar)=load_dataset(n_partitions=NUM_PARTITIONS,
                   client=client,
                   dataset_url=DATASET_URL_10PC,
                   raw_gz_path=RAW_GZ_PATH,
                   parquet_path=PARQUET_PATH,
                   parquet_path_workers=PARQUET_PATH,
                   col_names=COL_NAMES)
end=time.time()
elapsed=end-start
print(f"Time elapsed: {elapsed:.2f} s")
# Out:
# Downloading compressed dataset...
# Converting .gz -> Parquet chunk sizes...
# Parquet file created (compressed with snappy).
# Number of partitions before preprocessing: 64
# Constant columns: ['num_outbound_cmds', 'is_host_login']
# Computing global mean and std (first pass over data)...
# Distributed bag created with 32 partitions.
# Number of samples: 494021
# Time elapsed: 10.67 s

# %%
# if want to go back to original coordinates later
#print(mean_ar, '\n\n\n') 
#print(std_ar)

# %% [markdown]
# #### Check that loaded correctly

# %%
# global variable used in data_loader.py 
print(f"Number of initial features (should be 42): {len(COL_NAMES)}")
# Out:
# Number of initial features (should be 42): 42

# %%
lengths = X_bag.map(len).frequencies().compute() # length of every row- its unnormalized PMF
print("Feature count distribution (should be 37 for full dataset, see below):", lengths)
# Should show one unique length, 37 (see below)
# Out:
# Feature count distribution (should be 37 for full dataset, see below): [(36, 494021)]

# %%
n_points = X_bag.count().compute()
n_features = X_bag.map(len).take(1)[0] # since all rows have same length
print(f"Points: {n_points}, Features: {n_features}\n(Full dataset should contain 4898431 samples with 37 (=42 -1 label -3 non numeric -1 constant feature) numerical, non-constant features)")
# Out:
# Points: 494021, Features: 36
# (Full dataset should contain 4898431 samples with 37 (=42 -1 label -3 non numeric -1 constant feature) numerical, non-constant features)

# %%
has_nan = X_bag.map(lambda x: np.isnan(x).any()).any().compute()
has_inf = X_bag.map(lambda x: np.isinf(x).any()).any().compute()
print(f"Has NaN: {has_nan}, Has Inf: {has_inf}\n(Both must be False)")
# Out:
# Has NaN: False, Has Inf: False
# (Both must be False)

# %%
total = X_bag.reduction(
    lambda part: np.sum(np.vstack(list(part)), axis=0),
    lambda parts: np.sum(list(parts), axis=0)
).compute()
mean = total / n_points
means_vector=np.any(np.abs(mean)>1e-3)
print(f"Any column mean significantly different from zero: {means_vector==True}\n(Must be False)")
# Out:
# Any column mean significantly different from zero: False
# (Must be False)

# %%
sq_total = X_bag.reduction(
    lambda part: np.sum(np.vstack(list(part))**2, axis=0),
    lambda parts: np.sum(list(parts), axis=0)
).compute()

std = np.sqrt(sq_total / n_points - mean**2)
std_minus_one_vector=np.abs(std - 1)
print(f"Any column where std significantly different from one: {np.any(std_minus_one_vector > 1e-3)}\n(Must be False)")
# Out:
# Any column where std significantly different from one: False
# (Must be False)

# %%
sample_rows = X_bag.take(5)
for i, row in enumerate(sample_rows):
    print(f"Row {i}: shape={row.shape}, first 5 values={row[:5]}")
# Out:
# Row 0: shape=(36,), first 5 values=[-0.06779165 -0.00287852  0.13866427 -0.00667341 -0.04772014]
# Row 1: shape=(36,), first 5 values=[-0.06779165 -0.00281983 -0.01157786 -0.00667341 -0.04772014]
# Row 2: shape=(36,), first 5 values=[-0.06779165 -0.00282388  0.0141788  -0.00667341 -0.04772014]
# Row 3: shape=(36,), first 5 values=[-0.06779165 -0.00284007  0.0141788  -0.00667341 -0.04772014]
# Row 4: shape=(36,), first 5 values=[-0.06779165 -0.0028421   0.03521391 -0.00667341 -0.04772014]

# %%
# additional sanity check
print("Type of X_bag:", type(X_bag))
print("Number of partitions:", X_bag.npartitions)
# Out:
# Type of X_bag: <class 'dask.bag.core.Bag'>
# Number of partitions: 32

# %% [markdown]
# ## 5. Single run
#
# Runs a single combination of parameters (the ones defined in section 2) and prints the cost and execution time.

# %%
start=time.time()
result, _ = run_single_test(
    client,
    k=K, l=L, r=R,
    num_partitions=NUM_PARTITIONS,
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
    X_bag=X_bag
)
result
end=time.time()
elapsed=end-start
print(f"Time elapsed: {elapsed:.2f} s")
# Out:
#  -> Cost: 54213.38 | Time: 128.76s
# Time elapsed: 135.98 s

# %%
#cost =567232.43 
#cost_ten=cost * 1e-10
#print(f"(Cost equivalent to {cost_ten :.2f} * 10^10)")
minutes=elapsed/60
print(f"(Time elapsed equivalent to {minutes:.2f} minutes)")
# Out:
# (Time elapsed equivalent to 2.27 minutes)

# %% [markdown]
# Compare with:
# * Cost $19 \cdot 10^{10}$ ($k=500$, $l=0.5 k$, but $r=5$ instead - table 3.).
#   HOWEVER, note that here we standardized data beforehand!
# * Running time $69.0 \text{ min}$ for the same values (table 4)

# %% [markdown]
# ## 6. Benchmark multi-combinazione
#
# Testa più combinazioni di `(n_workers, partitions, l_over_k, r)` per diversi valori di `k`, e salva tutto in `./results`.
#
# **Nota:** il numero di worker effettivamente attivi nel cluster è quello impostato con `launch_cluster` in sezione 3 — la colonna `workers` qui sotto serve solo per etichettare/loggare i risultati, non riavvia il cluster.

# %%
combinations = [
    # (n_workers, num_partitions, l_over_k, r)
    (N_WORKERS, NUM_PARTITIONS+i, 1, R) for i in range(1,50,2)
]

K_VALUES = [1000]

df_results = run_benchmark(
    client, X,
    combinations=combinations,
    k_values=K_VALUES,
    label="kddcup99_benchmark",
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
    averaging_iterations = 10
)
df_results
# Out:
# Testing: k=1000, workers=8, partitions=65, l=1000 (l/k=1), r=10
#  Iterating 10 times.
#  -> Cost: 17974.17 | Time: 90.73s
#  -> Cost: 17841.91 | Time: 88.78s
#  -> Cost: 17905.34 | Time: 87.94s

# %% [markdown]
# ## 6.1 Analisi dati
#
# Per vedere i risultati ottenuti precedentemente

# %%
from benchmark_analysis import BenchmarkAnalyzer

analyzer = BenchmarkAnalyzer(
    data_path="/home/ubuntu/Project/working/results/kddcup99_benchmark_20260714_205025.csv",
    output_dir="/home/ubuntu/Project/working/results/plots",
    facet_cols=["k"],              # una figura per ogni valore (combinazione) di queste colonne
    x_col="partitions",               # variabile sull'asse x
    metrics=["cost", "time"],       # colonne di cui calcolare mean/std e plottare
)
grouped = analyzer.compute_grouped_stats(groupby_cols=["k", "partitions"])
analyzer.print_summary(grouped)
analyzer.plot_all(grouped)
# Out:
#    k  partitions    cost_mean  cost_std  time_mean   time_std  n_runs
# 1000          65 17919.131558 71.353358 137.874900 122.556448      10
# 1000          67 17922.735302 55.800857  84.647287   3.800118      10
# 1000          69 17960.141575 38.033450  82.895011   2.793958      10
# 1000          71 17920.767241 66.300495  84.256649   1.693807      10
# 1000          73 17913.972364 46.895644  84.713419   1.377970      10
# 1000          75 17932.509021 50.659729  83.529865   2.137052      10
# 1000          77 17927.165965 75.759642  80.110966   1.011836      10
# 1000          79 17942.269382 63.758669  82.471137   1.845440      10
# 1000          81 17932.161051 67.931189  82.661148   1.878459      10
# 1000          83 17942.208339 82.667241  81.995846   1.844266      10
# 1000          85 17928.294190 55.902298  84.188580   2.591723      10
# 1000          87 17949.266102 74.106023  82.515809   1.583006      10
# 1000          89 17906.945090 72.546749  80.900575   2.478579      10
# 1000          91 17948.373895 80.440730  82.160472   1.830746      10
# 1000          93 17942.345039 60.704127  82.876437   2.520125      10
# 1000          95 17926.738449 75.157565  82.546152   2.377803      10
# 1000          97 17933.458057 48.192022  84.179318   2.387334      10
# 1000          99 17935.128831 78.166522  84.779132   2.552964      10
# 1000         101 17887.943299 62.941850  83.890379   1.500811      10
# 1000         103 17935.612576 42.504432  82.340045   1.914682      10
# 1000         105 17941.567307 50.881610  85.025394   1.187877      10
# 1000         107 17924.933484 57.404589  84.886753   1.746575      10
# 1000         109 17927.626789 62.627146  85.469117   1.721623      10
# 1000         111 17952.719556 67.611271  85.877161   1.905459      10
# 1000         113 17916.218506 53.435213  86.544440   1.998807      10
# Saved /home/ubuntu/Project/working/results/plots/k_1000_partitions.png
# ['/home/ubuntu/Project/working/results/plots/k_1000_partitions.png']

# %% [markdown]
# ## 7. Spegnimento del cluster
#
# Da eseguire a fine lavoro, o prima di rilanciare `launch_cluster` con un `N_WORKERS` diverso.

# %%
shutdown_cluster(cluster, client)
# Out:
# Cluster e client chiusi.
