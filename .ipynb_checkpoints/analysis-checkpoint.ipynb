# %% [markdown]
# # K-means|| distribuito su Dask — Analisi
#
# Notebook di orchestrazione: avvia il cluster, carica il dataset, esegue i test (singola run o benchmark su più combinazioni) e salva i risultati in `./results`.
#
# Moduli usati:
# - `kmeans_parallel.py` — algoritmo k-means|| distribuito
# - `launch_cluster.py` — avvio/spegnimento del cluster Dask via SSH
# - `data_loader.py` — caricamento del dataset
# - `benchmark.py` — esecuzione dei test e salvataggio risultati

# %% [markdown]
# ## 1. Import

# %%
import numpy as np
import pandas as pd
from kmeans_parallel import kmeans_parallel
from launch_cluster import launch_cluster, shutdown_cluster
from data_loader import load_dataset
from benchmark import run_single_test, run_benchmark, calculate_inertia

# %% [markdown]
# ## 2. Parametri configurabili
#
# Modifica qui i valori per cambiare numero di worker, `k`, `l` (oversampling factor) e `r` (numero di round dell'inizializzazione parallela).

# %%
# --- Cluster ---
N_WORKERS = 8      # tra 1 e 8 (nodi disponibili in launch_cluster.py)
NUM_PARTITIONS = 8 * N_WORKERS   # regola empirica: >= n_threads_per_worker * n_workers

# --- Algoritmo k-means|| ---
K = 500                # numero di cluster finali
L = 250                # oversampling factor (assoluto). In alternativa: L = round(L_OVER_K * K)
R = 10                  # numero di round dell'inizializzazione parallela
MAX_ITER_FIT = 10      # iterazioni massime della fase di Lloyd's (fit)
SEED = 42

# %% [markdown]
# ## 3. Avvio del cluster

# %%
cluster, client = launch_cluster(N_WORKERS)
#clientclient.scheduler.address
# Out:
# Inizializzazione del cluster SSH con 8 worker...
# Worker selezionati: ['10.67.22.254', '10.67.22.34', '10.67.22.145', '10.67.22.121', '10.67.22.192', '10.67.22.18', '10.67.22.187', '10.67.22.48']
# 2026-07-13 22:40:05,789 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:05,788 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2026-07-13 22:40:05,819 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:05,818 - distributed.scheduler - INFO - State start
# 2026-07-13 22:40:05,823 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:05,823 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.194:8786
# 2026-07-13 22:40:07,465 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,467 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.254:33175'
# 2026-07-13 22:40:07,480 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,483 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.121:41395'
# 2026-07-13 22:40:07,484 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,486 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.145:36521'
# 2026-07-13 22:40:07,491 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,492 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.18:34539'
# 2026-07-13 22:40:07,492 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,490 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.48:46019'
# 2026-07-13 22:40:07,705 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,704 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.34:39781'
# 2026-07-13 22:40:07,744 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,744 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.187:41149'
# 2026-07-13 22:40:07,752 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,751 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.192:35651'
# 2026-07-13 22:40:07,757 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,759 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-xw2h6fa5', purging
# 2026-07-13 22:40:07,768 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,770 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.254:37327
# 2026-07-13 22:40:07,777 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,780 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-45x6gfns', purging
# 2026-07-13 22:40:07,780 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,782 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-bddqao77', purging
# 2026-07-13 22:40:07,788 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,790 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.121:33915
# 2026-07-13 22:40:07,790 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,788 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-m3d2irbe', purging
# 2026-07-13 22:40:07,791 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,793 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.145:43729
# 2026-07-13 22:40:07,801 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,799 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.48:36979
# 2026-07-13 22:40:07,834 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,835 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-35p_8v50', purging
# 2026-07-13 22:40:07,847 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:07,848 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.18:43109
# 2026-07-13 22:40:08,052 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,050 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-cfuk321l', purging
# 2026-07-13 22:40:08,064 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,063 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.34:37119
# 2026-07-13 22:40:08,089 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,089 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-r0kj73ye', purging
# 2026-07-13 22:40:08,094 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,094 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-k4avvy6w', purging
# 2026-07-13 22:40:08,101 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,101 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.192:41955
# 2026-07-13 22:40:08,106 - distributed.deploy.ssh - INFO - 2026-07-13 22:40:08,106 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.187:39419
# Cluster avviato e connessione stabilita con successo!

# %%
client.scheduler_info()
# Out:
# {'type': 'Scheduler',
#  'id': 'Scheduler-52c0d23e-6b1a-480a-b18f-c857b6c1c1ec',
#  'address': 'tcp://10.67.22.194:8786',
#  'services': {'dashboard': 8787},
#  'started': 1783982405.443483,
#  'n_workers': 8,
#  'total_threads': 64,
#  'total_memory': 66574635008,
#  'workers': {'tcp://10.67.22.121:33915': {'type': 'Worker',
#    'id': 'tcp://10.67.22.121:33915',
#    'host': '10.67.22.121',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-_pjchrdj',
#    'name': 'tcp://10.67.22.121:33915',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1784008894.820914,
#    'services': {'dashboard': 33225},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 90777488.15536326, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.002002239227294922,
#      'tick-duration': 0.499924898147583},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 27381,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 34288},
#     'event_loop_interval': 0.019970698356628416,
#     'cpu': 2.0,
#     'memory': 197971968,
#     'time': 1784008894.3162208,
#     'host_net_io': {'read_bps': 813.6620438439642,
#      'write_bps': 2023.159676584992},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.121:41395'},
#   'tcp://10.67.22.145:43729': {'type': 'Worker',
#    'id': 'tcp://10.67.22.145:43729',
#    'host': '10.67.22.145',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-ed5v0idy',
#    'name': 'tcp://10.67.22.145:43729',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1784008894.8160357,
#    'services': {'dashboard': 33643},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 90687891.56460436, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.0014164447784423828,
#      'tick-duration': 0.4992380142211914},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 28053,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 34848},
#     'event_loop_interval': 0.019988532066345214,
#     'cpu': 2.0,
#     'memory': 191873024,
#     'time': 1784008894.31569,
#     'host_net_io': {'read_bps': 681.1564735360511,
#      'write_bps': 1889.659894325819},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.145:36521'},
#   'tcp://10.67.22.187:39419': {'type': 'Worker',
#    'id': 'tcp://10.67.22.187:39419',
#    'host': '10.67.22.187',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-1k2h0_ys',
#    'name': 'tcp://10.67.22.187:39419',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1784008895.130848,
#    'services': {'dashboard': 46691},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 90649143.79474422, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.0031893253326416016,
#      'tick-duration': 0.4990220069885254},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 37444,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 34059},
#     'event_loop_interval': 0.020006046295166016,
#     'cpu': 6.0,
#     'memory': 205684736,
#     'time': 1784008894.629583,
#     'host_net_io': {'read_bps': 286.23561198131114,
#      'write_bps': 1497.2324319022428},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.187:41149'},
#   'tcp://10.67.22.18:43109': {'type': 'Worker',
#    'id': 'tcp://10.67.22.18:43109',
#    'host': '10.67.22.18',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-tdirbfdw',
#    'name': 'tcp://10.67.22.18:43109',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1784008894.866788,
#    'services': {'dashboard': 33781},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 90807053.53418995, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.001277923583984375,
#      'tick-duration': 0.4982616901397705},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 32074,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 34661},
#     'event_loop_interval': 0.019998717308044433,
#     'cpu': 2.0,
#     'memory': 195043328,
#     'time': 1784008894.3674285,
#     'host_net_io': {'read_bps': 2133.8142898902256,
#      'write_bps': 3341.709164392284},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.18:34539'},
#   'tcp://10.67.22.192:41955': {'type': 'Worker',
#    'id': 'tcp://10.67.22.192:41955',
#    'host': '10.67.22.192',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-c1s2hyv_',
#    'name': 'tcp://10.67.22.192:41955',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1784008895.1278138,
#    'services': {'dashboard': 44447},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 82231288.13635196, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.0031805038452148438,
#      'tick-duration': 0.5005249977111816},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 22899,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 35398},
#     'event_loop_interval': 0.019994964599609377,
#     'cpu': 6.0,
#     'memory': 194981888,
#     'time': 1784008894.6241837,
#     'host_net_io': {'read_bps': 418.0868976871363,
#      'write_bps': 1628.3384436235835},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 36},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.192:35651'}}}

# %% [markdown]
# ## 4. Caricamento del dataset

# %%
X = load_dataset("kddcup99", subset="SA", percent10=True)
#troppo grande il 100%
X.shape
# Out:
# Loading dataset...
# Dataset preprocessed. Shape: (100655, 38)
# (100655, 38)

# %% [markdown]
# ## 5. Singola run
#
# Esegue una sola combinazione di parametri (quelli definiti nella sezione 2) e stampa costo e tempo di esecuzione.

# %%
result, _ = run_single_test(
    client, X,
    k=K, l=L, r=R,
    num_partitions=NUM_PARTITIONS,
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
)
result
# Out:
#  -> Cost: 32024.50 | Time: 42.13s
# {'k': 500,
#  'l': 250,
#  'r': 8,
#  'partitions': 16,
#  'cost': np.float64(32024.501172765304),
#  'time': 42.12557506561279}

# %% [markdown]
# ## 6. Benchmark multi-combinazione
#
# Testa più combinazioni di `(n_workers, partitions, l_over_k, r)` per diversi valori di `k`, e salva tutto in `./results`.
#
# **Nota:** il numero di worker effettivamente attivi nel cluster è quello impostato con `launch_cluster` in sezione 3 — la colonna `workers` qui sotto serve solo per etichettare/loggare i risultati, non riavvia il cluster.

# %%
combinations = [
    # (n_workers, num_partitions, l_over_k, r)
    (N_WORKERS-6, NUM_PARTITIONS, 1, R),
    (N_WORKERS-5, NUM_PARTITIONS, 1, R),
    (N_WORKERS-4, NUM_PARTITIONS, 1, R),
    (N_WORKERS-3, NUM_PARTITIONS, 1, R),
    (N_WORKERS-2, NUM_PARTITIONS, 1, R),
    (N_WORKERS-1, NUM_PARTITIONS, 1, R),
    (N_WORKERS, NUM_PARTITIONS, 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*1.5), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*2), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*2.5), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*3), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*3.5), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*5), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*6), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*8), 1, R),
    (N_WORKERS, int(NUM_PARTITIONS*10), 1, R),
]

K_VALUES = [500, 1000]

df_results = run_benchmark(
    client, X,
    combinations=combinations,
    k_values=K_VALUES,
    label="kddcup99_benchmark",
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
    averaging_iterations = 15
)
df_results
# Out:
# Testing: k=500, workers=8, partitions=16, l=50 (l/k=0.1), r=15
#  Iterating 15 times.
#  -> Cost: 32211.91 | Time: 37.11s
#  -> Cost: 31841.05 | Time: 37.26s
#  -> Cost: 32528.42 | Time: 37.43s
#  -> Cost: 32218.68 | Time: 38.18s
#  -> Cost: 32451.95 | Time: 37.55s
#  -> Cost: 32362.49 | Time: 39.64s

# %% [markdown]
# ## 6.1 Analisi dati
#
# Per vedere i risultati ottenuti precedentemente

# %%
import pandas as pd
import matplotlib.pyplot as plt
data_dir = "/home/ubuntu/Project/working/results/kddcup99_benchmark_20260714_040919.csv"
df = pd.read_csv(data_dir)

# Group by k, l_over_k -> mean/std of cost and time across repeated runs
grouped = (
    df.groupby(['partition', 'l_over_k'])
      .agg(cost_mean=('cost', 'mean'),
           cost_std=('cost', 'std'),
           time_mean=('time', 'mean'),
           time_std=('time', 'std'),
           n_runs=('cost', 'size'))
      .reset_index()
      .sort_values(['k', 'l_over_k'])
)

print(grouped.to_string(index=False))

k_values = sorted(grouped['k'].unique())

for k in k_values:
    sub = grouped[grouped['k'] == k].sort_values('l_over_k')

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Cost plot
    axes[0].errorbar(sub['l_over_k'], sub['cost_mean'], yerr=sub['cost_std'],
                      marker='o', capsize=4, linestyle='-', color='tab:blue')
    axes[0].set_xlabel('l / k')
    axes[0].set_ylabel('Cost (mean ± std)')
    axes[0].set_title(f'Cost vs l/k (k={k})')
    axes[0].grid(True, alpha=0.3)

    # Time plot
    axes[1].errorbar(sub['l_over_k'], sub['time_mean'], yerr=sub['time_std'],
                      marker='o', capsize=4, linestyle='-', color='tab:orange')
    axes[1].set_xlabel('l / k')
    axes[1].set_ylabel('Time (mean ± std, s)')
    axes[1].set_title(f'Time vs l/k (k={k})')
    axes[1].grid(True, alpha=0.3)

    fig.suptitle(f'k = {k}')
    fig.tight_layout()
    outpath = f'/home/ubuntu/Project/working/results/plots/k_{k}_l_over_k.png'
    fig.savefig(outpath, dpi=150)
    plt.close(fig)
    print('Saved', outpath)
# Out:
#    k  l_over_k    cost_mean   cost_std  time_mean  time_std  n_runs
#  500       0.1 32286.553722 247.802710  38.455359  1.154221      15
#  500       0.5 31500.235382 137.809525  42.306573  2.155229      15
#  500       1.0 31469.411343 164.027835  56.279304  2.148953      15
#  500       2.0 31358.138880 162.182138  68.180947  2.441412      30
# 1000       0.1 18261.207239  66.330043  54.650030  1.617311      15
# 1000       0.5 17910.365878  68.053666  69.907582  2.628112      15
# 1000       1.0 17895.915106  57.864818  83.993203  1.975328      15
# 1000       2.0 17877.207187  55.604058 108.161970  2.475048      30
# Saved /home/ubuntu/Project/working/results/plots/k_500_l_over_k.png
# Saved /home/ubuntu/Project/working/results/plots/k_1000_l_over_k.png

# %%
from benchmark_analysis import BenchmarkAnalyzer

analyzer = BenchmarkAnalyzer(
    data_path="/home/ubuntu/Project/working/results/kddcup99_benchmark_20260714_040919.csv",
    output_dir="/home/ubuntu/Project/working/results/plots",
    facet_cols=["k"],              # una figura per ogni valore (combinazione) di queste colonne
    x_col="partitions",               # variabile sull'asse x
    metrics=["cost", "time"],       # colonne di cui calcolare mean/std e plottare
)
grouped = analyzer.compute_grouped_stats(groupby_cols=["k", "partitions"])
analyzer.print_summary(grouped)
analyzer.plot_all(grouped)
# Out:
#    k  partitions    cost_mean  cost_std  time_mean  time_std  n_runs
# 1000          16 17792.443683 48.424726  79.050110  3.907694     105
# 1000          24 17795.195491 49.789107  71.244147  3.817016      15
# 1000          32 17762.397327 55.734004  72.578497  3.916271      15
# 1000          40 17798.617730 52.902375  73.385953  4.750356      15
# 1000          48 17786.893170 72.599275  72.434963  3.244112      15
# 1000          56 17782.672467 49.256458  78.460376  3.804103      15
# 1000          80 17809.274939 53.805975  77.224743  1.694984      15
# 1000          96 17790.902935 69.011338  79.032739  2.341714      15
# 1000         128 17804.353175 58.935099  83.739562  2.325158      15
# 1000         160 17789.961156 73.970929  85.285267  2.241945      15
# Saved /home/ubuntu/Project/working/results/plots/k_1000_partitions.png
# ['/home/ubuntu/Project/working/results/plots/k_1000_partitions.png']

# %% [markdown]
# ## 7. Spegnimento del cluster
#
# Da eseguire a fine lavoro, o prima di rilanciare `launch_cluster` con un `N_WORKERS` diverso.

# %%
shutdown_cluster(cluster, client)
# Out:
# Cluster e client chiusi.
