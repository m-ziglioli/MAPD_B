# %% [markdown]
# # K-means|| distribuito su Dask — Analisi
#
# Notebook di orchestrazione: avvia il cluster, carica il dataset, esegue i test (singola run o benchmark su più combinazioni) e salva i risultati in `./results`.
#
# Moduli usati:
# - `kmeans_parallel.py` — algoritmo k-means|| distribuito
# - `launch_cluster.py` — avvio/spegnimento del cluster Dask via SSH
# - `data_loader.py` — caricamento del dataset
# - `benchmark.py` — esecuzione dei test e salvataggio risultati

# %% [markdown]
# ## 1. Import

# %%
import numpy as np
import pandas as pd
from kmeans_parallel import kmeans_parallel
from launch_cluster import launch_cluster, shutdown_cluster
from data_loader import load_dataset
from benchmark import run_single_test, run_benchmark, calculate_inertia

# %% [markdown]
# ## 2. Parametri configurabili
#
# Modifica qui i valori per cambiare numero di worker, `k`, `l` (oversampling factor) e `r` (numero di round dell'inizializzazione parallela).

# %%
# --- Cluster ---
N_WORKERS = 8      # tra 1 e 8 (nodi disponibili in launch_cluster.py)
NUM_PARTITIONS = 2 * N_WORKERS   # regola empirica: >= n_threads_per_worker * n_workers

# --- Algoritmo k-means|| ---
K = 500                # numero di cluster finali
L = 250                # oversampling factor (assoluto). In alternativa: L = round(L_OVER_K * K)
R = 8                  # numero di round dell'inizializzazione parallela
MAX_ITER_FIT = 10      # iterazioni massime della fase di Lloyd's (fit)
SEED = 42

# %% [markdown]
# ## 3. Avvio del cluster

# %%
cluster, client = launch_cluster(N_WORKERS)
#clientclient.scheduler.address
# Out:
# Inizializzazione del cluster SSH con 8 worker...
# Worker selezionati: ['10.67.22.254', '10.67.22.34', '10.67.22.145', '10.67.22.121', '10.67.22.192', '10.67.22.18', '10.67.22.187', '10.67.22.48']
# 2026-07-13 15:00:43,704 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:43,703 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2026-07-13 15:00:43,730 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:43,730 - distributed.scheduler - INFO - State start
# 2026-07-13 15:00:43,733 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:43,733 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.194:8786
# 2026-07-13 15:00:45,449 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,423 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.18:43691'
# 2026-07-13 15:00:45,451 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,461 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.121:35235'
# 2026-07-13 15:00:45,452 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,454 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.254:35679'
# 2026-07-13 15:00:45,455 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,461 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.145:39999'
# 2026-07-13 15:00:45,488 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,487 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.48:37485'
# 2026-07-13 15:00:45,643 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,642 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.34:43335'
# 2026-07-13 15:00:45,654 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,658 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.187:44225'
# 2026-07-13 15:00:45,669 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,663 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.192:43403'
# 2026-07-13 15:00:45,743 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,752 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-v9iexrz0', purging
# 2026-07-13 15:00:45,754 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,764 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.121:46675
# 2026-07-13 15:00:45,759 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,760 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-h634dz04', purging
# 2026-07-13 15:00:45,770 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,772 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.254:44843
# 2026-07-13 15:00:45,778 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,777 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-q0ds0cr6', purging
# 2026-07-13 15:00:45,782 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,756 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-bem5jkia', purging
# 2026-07-13 15:00:45,784 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,790 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-3tubm0fg', purging
# 2026-07-13 15:00:45,789 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,788 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.48:33101
# 2026-07-13 15:00:45,795 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,770 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.18:42021
# 2026-07-13 15:00:45,797 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:45,803 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.145:34671
# 2026-07-13 15:00:46,001 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,000 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-14h2ac9n', purging
# 2026-07-13 15:00:46,005 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,009 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-9tp_9har', purging
# 2026-07-13 15:00:46,013 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,013 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.34:33285
# 2026-07-13 15:00:46,018 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,022 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.187:37437
# 2026-07-13 15:00:46,032 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,025 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-r8zr3fsx', purging
# 2026-07-13 15:00:46,045 - distributed.deploy.ssh - INFO - 2026-07-13 15:00:46,038 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.192:42371
# Cluster avviato e connessione stabilita con successo!

# %%
client.scheduler_info()
# Out:
# {'type': 'Scheduler',
#  'id': 'Scheduler-4e95fa1a-870b-402b-8121-03b83212352c',
#  'address': 'tcp://10.67.22.194:8786',
#  'services': {'dashboard': 8787},
#  'started': 1783954843.3872597,
#  'n_workers': 8,
#  'total_threads': 64,
#  'total_memory': 66574635008,
#  'workers': {'tcp://10.67.22.121:46675': {'type': 'Worker',
#    'id': 'tcp://10.67.22.121:46675',
#    'host': '10.67.22.121',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-q6ir5nvf',
#    'name': 'tcp://10.67.22.121:46675',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1783954846.7881424,
#    'services': {'dashboard': 40541},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.02903008460998535,
#      'tick-duration': 0.9804534912109375},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 0},
#     'event_loop_interval': 0.02,
#     'cpu': 5.5,
#     'memory': 61681664,
#     'time': 1783954846.2948515,
#     'host_net_io': {'read_bps': 2495.924774203204,
#      'write_bps': 8395.551407153147},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 20},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.121:35235'},
#   'tcp://10.67.22.145:34671': {'type': 'Worker',
#    'id': 'tcp://10.67.22.145:34671',
#    'host': '10.67.22.145',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-d2xpew26',
#    'name': 'tcp://10.67.22.145:34671',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1783954846.8191774,
#    'services': {'dashboard': 46745},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.017513275146484375,
#      'tick-duration': 0.9817557334899902},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 0},
#     'event_loop_interval': 0.02,
#     'cpu': 5.6,
#     'memory': 61755392,
#     'time': 1783954846.3242772,
#     'host_net_io': {'read_bps': 2785.5604149176347,
#      'write_bps': 8576.593909088508},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 20},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.145:39999'},
#   'tcp://10.67.22.187:37437': {'type': 'Worker',
#    'id': 'tcp://10.67.22.187:37437',
#    'host': '10.67.22.187',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-1x0_41vt',
#    'name': 'tcp://10.67.22.187:37437',
#    'nthreads': 8,
#    'memory_limit': 8321835008,
#    'last_seen': 1783954847.0463881,
#    'services': {'dashboard': 38025},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.02061319351196289,
#      'tick-duration': 0.9819736480712891},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 0},
#     'event_loop_interval': 0.02,
#     'cpu': 11.2,
#     'memory': 62148608,
#     'time': 1783954846.545389,
#     'host_net_io': {'read_bps': 2153.757660523222,
#      'write_bps': 7420.368189771414},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 20},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.187:44225'},
#   'tcp://10.67.22.18:42021': {'type': 'Worker',
#    'id': 'tcp://10.67.22.18:42021',
#    'host': '10.67.22.18',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-pptpy75g',
#    'name': 'tcp://10.67.22.18:42021',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1783954846.8188834,
#    'services': {'dashboard': 42217},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.01783919334411621,
#      'tick-duration': 0.9804725646972656},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 0},
#     'event_loop_interval': 0.02,
#     'cpu': 7.5,
#     'memory': 61894656,
#     'time': 1783954846.2910714,
#     'host_net_io': {'read_bps': 2778.291036739297,
#      'write_bps': 8629.199488603903},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 20},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.18:43691'},
#   'tcp://10.67.22.192:42371': {'type': 'Worker',
#    'id': 'tcp://10.67.22.192:42371',
#    'host': '10.67.22.192',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-ymwtpjy6',
#    'name': 'tcp://10.67.22.192:42371',
#    'nthreads': 8,
#    'memory_limit': 8321826816,
#    'last_seen': 1783954847.0734851,
#    'services': {'dashboard': 37189},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.02000737190246582,
#      'tick-duration': 0.9804949760437012},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
#      'outgoing_bytes': 0,
#      'outgoing_count': 0,
#      'outgoing_count_total': 0},
#     'event_loop_interval': 0.02,
#     'cpu': 11.2,
#     'memory': 62115840,
#     'time': 1783954846.5610309,
#     'host_net_io': {'read_bps': 2404.2161232711173,
#      'write_bps': 8253.726379578726},
#     'host_disk_io': {'read_bps': 0.0, 'write_bps': 0.0},
#     'num_fds': 20},
#    'status': 'running',
#    'nanny': 'tcp://10.67.22.192:43403'}}}

# %% [markdown]
# ## 4. Caricamento del dataset

# %%
X = load_dataset("kddcup99", subset="SA", percent10=True)
X.shape
# Out:
# Loading dataset...
# Dataset preprocessed. Shape: (100655, 38)
# (100655, 38)

# %% [markdown]
# ## 5. Singola run
#
# Esegue una sola combinazione di parametri (quelli definiti nella sezione 2) e stampa costo e tempo di esecuzione.

# %%
result, X_bag = run_single_test(
    client, X,
    k=K, l=L, r=R,
    num_partitions=NUM_PARTITIONS,
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
)
result
# Out:
#  -> Cost: 32024.50 | Time: 42.13s
# {'k': 500,
#  'l': 250,
#  'r': 8,
#  'partitions': 16,
#  'cost': np.float64(32024.501172765304),
#  'time': 42.12557506561279}

# %% [markdown]
# ## 6. Benchmark multi-combinazione
#
# Testa più combinazioni di `(n_workers, partitions, l_over_k, r)` per diversi valori di `k`, e salva tutto in `./results`.
#
# **Nota:** il numero di worker effettivamente attivi nel cluster è quello impostato con `launch_cluster` in sezione 3 — la colonna `workers` qui sotto serve solo per etichettare/loggare i risultati, non riavvia il cluster.

# %%
combinations = [
    # (n_workers, num_partitions, l_over_k, r)
    (N_WORKERS, NUM_PARTITIONS, 0.1, R),
    (N_WORKERS, NUM_PARTITIONS, 0.5, R),
    (N_WORKERS, NUM_PARTITIONS, 1.0, R),
    (N_WORKERS, NUM_PARTITIONS, 2.0, R),
]

K_VALUES = [500, 1000]

df_results = run_benchmark(
    client, X,
    combinations=combinations,
    k_values=K_VALUES,
    label="kddcup99_benchmark",
    max_iter_fit=MAX_ITER_FIT,
    seed=SEED,
)
df_results

# %% [markdown]
# ## 7. Spegnimento del cluster
#
# Da eseguire a fine lavoro, o prima di rilanciare `launch_cluster` con un `N_WORKERS` diverso.

# %%
shutdown_cluster(cluster, client)
# Out:
# Cluster e client chiusi.
